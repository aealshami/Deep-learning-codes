# %% [markdown]
# # Image Application: cat or not?
#
# **After this assignment you will be able to:**
# - Build and apply a deep neural network to supervised learning.
# - Learn how to do data normalization
# - learn how to do weight initialization
# - Learn how to use regularization
#
# Let's get started!

# %% [markdown]
# ## 1 - Packages

# %% [markdown]
# **Exercise**: Please mount your Google drive, and set up your working folder here.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
# start your code here
os.chdir("/content/drive/MyDrive/HW-DL/Homework3") # change your working folder here
# end your code here

# %% [markdown]
# Let's first import all the packages that you will need during this assignment.
# - [numpy](https://www.numpy.org/) is the fundamental package for scientific computing with Python.
# - [matplotlib](http://matplotlib.org) is a library to plot graphs in Python.
# - [h5py](http://www.h5py.org) is a common package to interact with a dataset that is stored on an H5 file.
# - [PIL](http://www.pythonware.com/products/pil/) and [scipy](https://www.scipy.org/) are used here to test your model with your own picture at the end.
# - dnn_app_utils provides the customized functions that will be used in this notebook.
# - np.random.seed(1) is used to keep all the random function calls consistent. It will help us grade your work.

# %%
import time
import numpy as np
import tensorflow as tf
import h5py
import matplotlib.pyplot as plt
import dnn_app_utils_v3 as du
from skimage.transform import rescale, resize, downscale_local_mean

# refresh 'planar_utils' module
import imp
imp.reload(du)

# %matplotlib inline
plt.rcParams['figure.figsize'] = (5.0, 4.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# %load_ext autoreload
# %autoreload 2

np.random.seed(1)
tf.random.set_seed(1)

# %% [markdown]
# ## 2 - Dataset
#
# **Problem Statement**: You are given a dataset ("data.h5") containing:
#     - a training set of m_train images labelled as cat (1) or non-cat (0)
#     - a test set of m_test images labelled as cat and non-cat
#     - each image is of shape (num_px, num_px, 3) where 3 is for the 3 channels (RGB).
#
# Let's get more familiar with the dataset. Load the data by running the cell below.
#
# The training input and output are stored in 'train_x_orig' and 'train_y'. The test input and output are stored in 'test_x_orig' and 'test_y'.

# %%
train_x_orig, train_y, test_x_orig, test_y, classes = du.load_data()
#print(classes)

# %% [markdown]
# The following code will show you an image in the dataset. Feel free to change the index and re-run the cell multiple times to see other images.

# %%
# Example of a picture
index = 200
plt.imshow(train_x_orig[index])
print("y = " + str(train_y[index,0]) + ". It's a " + classes[train_y[index,0]].decode("utf-8") +  " picture.")
#print(train_x_orig[index].shape,train_x_orig[index])
# Out:
# y = 1. It's a cat picture.

# %% [markdown]
# Let's explore more about the training data. We are curious about the shape of each image and can use 'train_x_orig[index].shape' to expore it.
# **Exercise**: Can you tell what the pixel number of each image is?

# %%
# Explore your dataset 
image_shape=train_x_orig[index].shape
print("Each image is of size: ", image_shape)
#start your code here
num_px= 209   # the number of pixels in each column of the image. Hint: The 1st element in image_shape indicates this number?
#end your code here
print('Number of pixels in each column of the image:', num_px)
# Out:
# Each image is of size:  (64, 64, 3)
# Number of pixels in each column of the image: 209

# %% [markdown]
# **Expected result:**
#
# Each image is of size:  (64, 64, 3)
#
# Number of pixels in each column of the image: 209

# %% [markdown]
# We just take a close look at an image of the image set. Now, let's take a look at the whole training set.
#
# **Exercise**: The first 4 lines in the following cell print out the shape of the trining images. There are 209 images, and each image has 64 by 64 pixcels and GRB color.
#
# Please print out the shape of the test input (stored in `test_x_orig`) and output (stored in `test_y`) data, and tell how many images we have in the test data.

# %%
train_x_shape=train_x_orig.shape
m_train = train_x_shape[0]
print ("train_x_orig shape: ",train_x_shape)
print ("Number of training examples: " ,m_train)
# start your code here
test_x_shape= test_x_orig.shape
test_y_shape= test_y.shape
m_test = test_x_shape[0]
# end your code here

print ("test_x_orig shape: " ,test_x_shape)
print ("test_y shape: " , test_y_shape)
print ("Number of test examples: " ,m_test)
# Out:
# train_x_orig shape:  (209, 64, 64, 3)
# Number of training examples:  209
# test_x_orig shape:  (50, 64, 64, 3)
# test_y shape:  (50, 1)
# Number of test examples:  50

# %% [markdown]
# **Expected result:**
#
# train_x_orig shape:  (209, 64, 64, 3)
#
# Number of training examples:  209
#
# test_x_orig shape:  (50, 64, 64, 3)
#
# test_y shape:  (50, 1)
#
# Number of test examples:  50

# %% [markdown]
# As mentioned in our lecture, you reshape and standardize the images before feeding them to the network. The code is given in the cell below.
#
# ![alt text](https://drive.google.com/uc?id=1TVZDDvQUKuSMUqMtS7Ahessd3-H8bqq9)
# <caption><center> <u>Figure 1</u>: Image to vector conversion. <br> </center></caption>

# %%
# Reshape the training and test examples 
train_x_flatten = train_x_orig.reshape(train_x_shape[0], -1)   # The "-1" makes reshape flatten the remaining dimensions
test_x_flatten = test_x_orig.reshape(test_x_orig.shape[0], -1)

# %% [markdown]
# Data normalization can help us accelerate the training process. The RGB values of an image are integers in the range of [0,255]. We can normalize the training images to have the feature values between 0 and 1 by using `train_x = train_x_flatten/255.0`.
#
# **Exercise**: We normalize the training images using `train_x = train_x_flatten/255.0` in the 1st line. Please normalize the test images to have feature values between 0 and 1.

# %%
# Standardize data to have feature values between 0 and 1.
train_x = train_x_flatten/255.0

#start your code here
test_x = test_x_flatten/255.0
#end your code here

print ("train_x's shape: " + str(train_x.shape))
print ("test_x's shape: " + str(test_x.shape))
print ("train_y's shape: " + str(train_y.shape))
print ("test_y's shape: " + str(test_y.shape))
# Out:
# train_x's shape: (209, 12288)
# test_x's shape: (50, 12288)
# train_y's shape: (209, 1)
# test_y's shape: (50, 1)

# %% [markdown]
# **Expected result:**
#
# train_x's shape: (209, 12288)
#
# test_x's shape: (50, 12288)
#
# train_y's shape: (209, 1)
#
# test_y's shape: (50, 1)

# %% [markdown]
# ###3- Build your neural network ###
# Now, we are going to use the skills in the first module to build our neural network.
#
# Excep the input layer, you can use
#
# `tf.keras.layers.Dense(20,activation='relu',
#                             kernel_initializer='glorot_uniform',
#                             bias_initializer='zeros')`
#
# to build the layers. In this example, we have 20 neurons in this layer, use 'relu' as the activation function, initialize our weight randomly using 'glorot_uniform', and our bias is initialized to be 'zeros'.
#
# First, we will need an input layer. How many neurons will you need in the input layer? Hint: how many elements does every training input have?
#
# Second, we will build several hidden layers. You are free to choose the number of neurons in every hidden layer.
#
# Last, we will build the output layer. How many neurons will you need in the output layer? Which activation function is more suitale in this problem? Hint: how many elements does every training output have? What is the range of the training output?

# %%
tf.random.set_seed(1) # we fixed the seed of the random number generator, so every time running this code, we can have the same results.

# start your code here
cat_model=tf.keras.Sequential([
    tf.keras.layers.InputLayer(input_shape=(12288)), # how many elements are there in every training image?
    tf.keras.layers.Dense(50,activation='relu', # in layer 1, we will have 20 neurons and use 'relu' as the activation function
                            kernel_initializer='glorot_uniform', # we will randomly choose the initial weight using the 'glorot_uniform' method
                            bias_initializer='zeros'), # we will initialize all bias to be zeros.
    tf.keras.layers.Dense(20,activation='relu', # in layer 1, we will have 20 neurons and use 'relu' as the activation function
                            kernel_initializer='glorot_uniform', # we will randomly choose the initial weight using the 'glorot_uniform' method
                            bias_initializer='zeros'), # we will initialize all bias to be zeros.
    tf.keras.layers.Dense(10,activation='relu', # in layer 1, we will have 20 neurons and use 'relu' as the activation function
                            kernel_initializer='glorot_uniform', # we will randomly choose the initial weight using the 'glorot_uniform' method
                            bias_initializer='zeros'), # we will initialize all bias to be zeros.                        
    #please follow the example of layer 1 to add more hidden layers here. 

    # End adding hidden layers                    
    tf.keras.layers.Dense(1,activation='sigmoid', # how many elements are there in every training output
                            kernel_initializer='glorot_uniform',
                            bias_initializer='zeros'),
])
# end your code here
cat_model.summary()
# Out:
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_34 (Dense)            (None, 50)                614450
#
#  dense_35 (Dense)            (None, 20)                1020
#
#  dense_36 (Dense)            (None, 10)                210
#
#  dense_37 (Dense)            (None, 1)                 11
#
# =================================================================
# Total params: 615,691
# Trainable params: 615,691
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Now, let's compile the model. When comiling your model, you will need to specify the optimizer, the loss function, and the metrics.
#
# For optimizers, the most popular ones are 'Adam' and its derivatives. You can also try 'RMSprop' and 'SGD' to see which one works better for you. You might need adjust the learning rate to acceperate the training process.
#
# For loss functions, our problem is a two-class classification problem. The most popular loss function would be 'BinaryCrossentropy'. If this is a multiple-class classification problem, you probably want to try 'CategoricalCrossentropy' or 'SparseCategoricalCrossentropy'.
#
# For the metrics, we want to know the accuracy of our model. Therefore, I would recommend 'accuracy'.

# %%
# start your code here
cat_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),  # Optimizer. Please change 'None' to some meaningful learning rate which is usually <1
    # Loss function to minimize
    loss=tf.keras.losses.BinaryCrossentropy(),
    # List of metrics to monitor
    metrics=['accuracy'],
                 )
# end your code here

# %% [markdown]
# It's time to train.
#
# We can plot training history. It can help us to adjust the parameters.
#
# If the training loss increases, we may want to decrease the `learning_rate`.
#
# If the training loss has large vibration, we may want to decrease the `learning_rate`.
#
# If the training loss decreases too slowly, we need to increase `learning_rate`.
#
# If the training loss decreases at a good speed, but ends up large, we may want to increase the epoch number.

# %%
# start your code here
history = cat_model.fit(
    train_x, # input data
    train_y, # real output data
    epochs=500, # how many iterations do you want to train your model? Your data will be reused to train the model for the number of epochs. I trained 5 min for this model
)
# end your code here. 
plt.figure()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['loss','val_loss'])
# Out:
# Epoch 1/500
# 7/7 [==============================] - 1s 12ms/step - loss: 9.5075 - accuracy: 0.5789
# Epoch 2/500
# 7/7 [==============================] - 0s 11ms/step - loss: 2.6244 - accuracy: 0.4450
# Epoch 3/500
# 7/7 [==============================] - 0s 11ms/step - loss: 1.0954 - accuracy: 0.5455
# Epoch 4/500
# 7/7 [==============================] - 0s 11ms/step - loss: 0.8181 - accuracy: 0.5598
# Epoch 5/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.7274 - accuracy: 0.6651
# Epoch 6/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.8250 - accuracy: 0.6124
# Epoch 7/500
# 7/7 [==============================] - 0s 8ms/step - loss: 1.7685 - accuracy: 0.5120
# Epoch 8/500
# 7/7 [==============================] - 0s 10ms/step - loss: 1.5255 - accuracy: 0.5885
# Epoch 9/500
# 7/7 [==============================] - 0s 8ms/step - loss: 1.1201 - accuracy: 0.6029
# Epoch 10/500
# 7/7 [==============================] - 0s 7ms/step - loss: 0.9056 - accuracy: 0.6172
# Epoch 11/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.5313 - accuracy: 0.7321
# Epoch 12/500
# 7/7 [==============================] - 0s 10ms/step - loss: 0.5089 - accuracy: 0.7177
# Epoch 13/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.4728 - accuracy: 0.7799
# Epoch 14/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.4978 - accuracy: 0.7751
# Epoch 15/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.4778 - accuracy: 0.7990
# Epoch 16/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.4410 - accuracy: 0.7943
# Epoch 17/500
# 7/7 [==============================] - 0s 11ms/step - loss: 0.5930 - accuracy: 0.6986
# Epoch 18/500
# 7/7 [==============================] - 0s 11ms/step - loss: 0.4563 - accuracy: 0.8038
# Epoch 19/500
# 7/7 [==============================] - 0s 11ms/step - loss: 0.4201 - accuracy: 0.8278
# Epoch 20/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.4065 - accuracy: 0.8134
# Epoch 21/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3810 - accuracy: 0.8469
# Epoch 22/500
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3568 - accuracy: 0.8517
# Epoch 23/500
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3527 - accuracy: 0.8278
# Epoch 24/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3747 - accuracy: 0.8230
# Epoch 25/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3359 - accuracy: 0.8517
# Epoch 26/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3084 - accuracy: 0.8852
# Epoch 27/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3153 - accuracy: 0.8804
# Epoch 28/500
# 7/7 [==============================] - 0s 9ms/step - loss: 0.6033 - accuracy: 0.7751
# Epoch 29/500
# 7/7 [==============================] - 0s 10ms/step - loss: 0.5058 - accuracy: 0.7656
# Epoch 30/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3989 - accuracy: 0.7990
# Epoch 31/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3755 - accuracy: 0.8230
# Epoch 32/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.4390 - accuracy: 0.8230
# Epoch 33/500
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3439 - accuracy: 0.8373
# Epoch 34/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.2981 - accuracy: 0.8612
# Epoch 35/500
# 7/7 [==============================] - 0s 9ms/step - loss: 0.2427 - accuracy: 0.8995
# Epoch 36/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.2079 - accuracy: 0.9282
# Epoch 37/500
# 7/7 [==============================] - 0s 9ms/step - loss: 0.1998 - accuracy: 0.9282
# Epoch 38/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1803 - accuracy: 0.9474
# Epoch 39/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1706 - accuracy: 0.9617
# Epoch 40/500
# 7/7 [==============================] - 0s 9ms/step - loss: 0.1578 - accuracy: 0.9474
# Epoch 41/500
# 7/7 [==============================] - 0s 11ms/step - loss: 0.1910 - accuracy: 0.9330
# Epoch 42/500
# 7/7 [==============================] - 0s 11ms/step - loss: 0.2086 - accuracy: 0.9187
# Epoch 43/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1756 - accuracy: 0.9474
# Epoch 44/500
# 7/7 [==============================] - 0s 9ms/step - loss: 0.2677 - accuracy: 0.9043
# Epoch 45/500
# 7/7 [==============================] - 0s 9ms/step - loss: 0.1740 - accuracy: 0.9617
# Epoch 46/500
# 7/7 [==============================] - 0s 9ms/step - loss: 0.1270 - accuracy: 0.9665
# Epoch 47/500
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0918 - accuracy: 0.9809
# Epoch 48/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1208 - accuracy: 0.9665
# Epoch 49/500
# 7/7 [==============================] - 0s 10ms/step - loss: 0.1085 - accuracy: 0.9665
# Epoch 50/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0738 - accuracy: 0.9809
# Epoch 51/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0890 - accuracy: 0.9809
# Epoch 52/500
# 7/7 [==============================] - 0s 9ms/step - loss: 0.1115 - accuracy: 0.9617
# Epoch 53/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1090 - accuracy: 0.9617
# Epoch 54/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3634 - accuracy: 0.8469
# Epoch 55/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1768 - accuracy: 0.9234
# Epoch 56/500
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0820 - accuracy: 0.9856
# Epoch 57/500
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0549 - accuracy: 0.9952
# Epoch 58/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0854 - accuracy: 0.9761
# Epoch 59/500
# 7/7 [==============================] - 0s 10ms/step - loss: 0.1485 - accuracy: 0.9426
# Epoch 60/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0438 - accuracy: 0.9856
# Epoch 61/500
# 7/7 [==============================] - 0s 10ms/step - loss: 0.1028 - accuracy: 0.9569
# Epoch 62/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.2668 - accuracy: 0.8900
# Epoch 63/500
# 7/7 [==============================] - 0s 9ms/step - loss: 0.4554 - accuracy: 0.8565
# Epoch 64/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.4957 - accuracy: 0.8756
# Epoch 65/500
# 7/7 [==============================] - 0s 9ms/step - loss: 0.5033 - accuracy: 0.8230
# Epoch 66/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1504 - accuracy: 0.9282
# Epoch 67/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1888 - accuracy: 0.9187
# Epoch 68/500
# 7/7 [==============================] - 0s 9ms/step - loss: 0.1277 - accuracy: 0.9426
# Epoch 69/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0826 - accuracy: 0.9809
# Epoch 70/500
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0525 - accuracy: 0.9856
# Epoch 71/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0661 - accuracy: 0.9856
# Epoch 72/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0435 - accuracy: 0.9952
# Epoch 73/500
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0273 - accuracy: 1.0000
# Epoch 74/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0270 - accuracy: 0.9952
# Epoch 75/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0214 - accuracy: 1.0000
# Epoch 76/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0188 - accuracy: 1.0000
# Epoch 77/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0085 - accuracy: 1.0000
# Epoch 78/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0264 - accuracy: 0.9904
# Epoch 79/500
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1944 - accuracy: 0.9330
# Epoch 80/500
# 7/7 [==============================] - 0s 10ms/step - loss: 0.1842 - accuracy: 0.9426
# Epoch 81/500
# 7/7 [==============================] - 0s 11ms/step - loss: 0.1640 - accuracy: 0.9330
# Epoch 82/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0796 - accuracy: 0.9713
# Epoch 83/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0598 - accuracy: 0.9809
# Epoch 84/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1982 - accuracy: 0.9282
# Epoch 85/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1618 - accuracy: 0.9474
# Epoch 86/500
# 7/7 [==============================] - 0s 9ms/step - loss: 0.1172 - accuracy: 0.9426
# Epoch 87/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0775 - accuracy: 0.9713
# Epoch 88/500
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0495 - accuracy: 0.9809
# Epoch 89/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0269 - accuracy: 0.9952
# Epoch 90/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0180 - accuracy: 0.9952
# Epoch 91/500
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0195 - accuracy: 0.9952
# Epoch 92/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0186 - accuracy: 1.0000
# Epoch 93/500
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0109 - accuracy: 1.0000
# Epoch 94/500
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0084 - accuracy: 1.0000
# Epoch 95/500
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0063 - accuracy: 1.0000
# Epoch 96/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 97/500
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 98/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 99/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 100/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 101/500
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 102/500
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 103/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 104/500
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 105/500
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 106/500
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 107/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 108/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 109/500
# 7/7 [==============================] - 0s 9ms/step - loss: 9.4530e-04 - accuracy: 1.0000
# Epoch 110/500
# 7/7 [==============================] - 0s 11ms/step - loss: 8.6827e-04 - accuracy: 1.0000
# Epoch 111/500
# 7/7 [==============================] - 0s 10ms/step - loss: 7.9314e-04 - accuracy: 1.0000
# Epoch 112/500
# 7/7 [==============================] - 0s 8ms/step - loss: 7.2641e-04 - accuracy: 1.0000
# Epoch 113/500
# 7/7 [==============================] - 0s 8ms/step - loss: 6.8092e-04 - accuracy: 1.0000
# Epoch 114/500
# 7/7 [==============================] - 0s 8ms/step - loss: 6.3655e-04 - accuracy: 1.0000
# Epoch 115/500
# 7/7 [==============================] - 0s 7ms/step - loss: 6.0115e-04 - accuracy: 1.0000
# Epoch 116/500
# 7/7 [==============================] - 0s 9ms/step - loss: 5.7184e-04 - accuracy: 1.0000
# Epoch 117/500
# 7/7 [==============================] - 0s 9ms/step - loss: 5.4198e-04 - accuracy: 1.0000
# Epoch 118/500
# 7/7 [==============================] - 0s 9ms/step - loss: 5.2356e-04 - accuracy: 1.0000
# Epoch 119/500
# 7/7 [==============================] - 0s 8ms/step - loss: 5.0303e-04 - accuracy: 1.0000
# Epoch 120/500
# 7/7 [==============================] - 0s 8ms/step - loss: 4.7845e-04 - accuracy: 1.0000
# Epoch 121/500
# 7/7 [==============================] - 0s 8ms/step - loss: 4.5890e-04 - accuracy: 1.0000
# Epoch 122/500
# 7/7 [==============================] - 0s 8ms/step - loss: 4.4228e-04 - accuracy: 1.0000
# Epoch 123/500
# 7/7 [==============================] - 0s 8ms/step - loss: 4.2620e-04 - accuracy: 1.0000
# Epoch 124/500
# 7/7 [==============================] - 0s 8ms/step - loss: 4.1187e-04 - accuracy: 1.0000
# Epoch 125/500
# 7/7 [==============================] - 0s 10ms/step - loss: 3.9952e-04 - accuracy: 1.0000
# Epoch 126/500
# 7/7 [==============================] - 0s 8ms/step - loss: 3.8807e-04 - accuracy: 1.0000
# Epoch 127/500
# 7/7 [==============================] - 0s 8ms/step - loss: 3.7628e-04 - accuracy: 1.0000
# Epoch 128/500
# 7/7 [==============================] - 0s 8ms/step - loss: 3.6704e-04 - accuracy: 1.0000
# Epoch 129/500
# 7/7 [==============================] - 0s 8ms/step - loss: 3.5894e-04 - accuracy: 1.0000
# Epoch 130/500
# 7/7 [==============================] - 0s 8ms/step - loss: 3.4711e-04 - accuracy: 1.0000
# Epoch 131/500
# 7/7 [==============================] - 0s 8ms/step - loss: 3.3789e-04 - accuracy: 1.0000
# Epoch 132/500
# 7/7 [==============================] - 0s 9ms/step - loss: 3.3448e-04 - accuracy: 1.0000
# Epoch 133/500
# 7/7 [==============================] - 0s 8ms/step - loss: 3.2429e-04 - accuracy: 1.0000
# Epoch 134/500
# 7/7 [==============================] - 0s 9ms/step - loss: 3.1710e-04 - accuracy: 1.0000
# Epoch 135/500
# 7/7 [==============================] - 0s 8ms/step - loss: 3.0989e-04 - accuracy: 1.0000
# Epoch 136/500
# 7/7 [==============================] - 0s 10ms/step - loss: 3.0403e-04 - accuracy: 1.0000
# Epoch 137/500
# 7/7 [==============================] - 0s 8ms/step - loss: 2.9541e-04 - accuracy: 1.0000
# Epoch 138/500
# 7/7 [==============================] - 0s 8ms/step - loss: 2.9182e-04 - accuracy: 1.0000
# Epoch 139/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.8345e-04 - accuracy: 1.0000
# Epoch 140/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.8008e-04 - accuracy: 1.0000
# Epoch 141/500
# 7/7 [==============================] - 0s 8ms/step - loss: 2.7820e-04 - accuracy: 1.0000
# Epoch 142/500
# 7/7 [==============================] - 0s 8ms/step - loss: 2.6963e-04 - accuracy: 1.0000
# Epoch 143/500
# 7/7 [==============================] - 0s 8ms/step - loss: 2.6617e-04 - accuracy: 1.0000
# Epoch 144/500
# 7/7 [==============================] - 0s 10ms/step - loss: 2.5992e-04 - accuracy: 1.0000
# Epoch 145/500
# 7/7 [==============================] - 0s 10ms/step - loss: 2.5759e-04 - accuracy: 1.0000
# Epoch 146/500
# 7/7 [==============================] - 0s 11ms/step - loss: 2.5244e-04 - accuracy: 1.0000
# Epoch 147/500
# 7/7 [==============================] - 0s 8ms/step - loss: 2.4918e-04 - accuracy: 1.0000
# Epoch 148/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.4345e-04 - accuracy: 1.0000
# Epoch 149/500
# 7/7 [==============================] - 0s 10ms/step - loss: 2.4091e-04 - accuracy: 1.0000
# Epoch 150/500
# 7/7 [==============================] - 0s 8ms/step - loss: 2.3713e-04 - accuracy: 1.0000
# Epoch 151/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.3394e-04 - accuracy: 1.0000
# Epoch 152/500
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2978e-04 - accuracy: 1.0000
# Epoch 153/500
# 7/7 [==============================] - 0s 8ms/step - loss: 2.2671e-04 - accuracy: 1.0000
# Epoch 154/500
# 7/7 [==============================] - 0s 13ms/step - loss: 2.2480e-04 - accuracy: 1.0000
# Epoch 155/500
# 7/7 [==============================] - 0s 8ms/step - loss: 2.2137e-04 - accuracy: 1.0000
# Epoch 156/500
# 7/7 [==============================] - 0s 8ms/step - loss: 2.2098e-04 - accuracy: 1.0000
# Epoch 157/500
# 7/7 [==============================] - 0s 8ms/step - loss: 2.1395e-04 - accuracy: 1.0000
# Epoch 158/500
# 7/7 [==============================] - 0s 8ms/step - loss: 2.1355e-04 - accuracy: 1.0000
# Epoch 159/500
# 7/7 [==============================] - 0s 11ms/step - loss: 2.1164e-04 - accuracy: 1.0000
# Epoch 160/500
# 7/7 [==============================] - 0s 8ms/step - loss: 2.0674e-04 - accuracy: 1.0000
# Epoch 161/500
# 7/7 [==============================] - 0s 8ms/step - loss: 2.0569e-04 - accuracy: 1.0000
# Epoch 162/500
# 7/7 [==============================] - 0s 8ms/step - loss: 2.0458e-04 - accuracy: 1.0000
# Epoch 163/500
# 7/7 [==============================] - 0s 8ms/step - loss: 2.0149e-04 - accuracy: 1.0000
# Epoch 164/500
# 7/7 [==============================] - 0s 10ms/step - loss: 1.9766e-04 - accuracy: 1.0000
# Epoch 165/500
# 7/7 [==============================] - 0s 12ms/step - loss: 1.9712e-04 - accuracy: 1.0000
# Epoch 166/500
# 7/7 [==============================] - 0s 10ms/step - loss: 1.9385e-04 - accuracy: 1.0000
# Epoch 167/500
# 7/7 [==============================] - 0s 8ms/step - loss: 1.9043e-04 - accuracy: 1.0000
# Epoch 168/500
# 7/7 [==============================] - 0s 9ms/step - loss: 1.8903e-04 - accuracy: 1.0000
# Epoch 169/500
# 7/7 [==============================] - 0s 9ms/step - loss: 1.8740e-04 - accuracy: 1.0000
# Epoch 170/500
# 7/7 [==============================] - 0s 11ms/step - loss: 1.8500e-04 - accuracy: 1.0000
# Epoch 171/500
# 7/7 [==============================] - 0s 8ms/step - loss: 1.8263e-04 - accuracy: 1.0000
# Epoch 172/500
# 7/7 [==============================] - 0s 8ms/step - loss: 1.8052e-04 - accuracy: 1.0000
# Epoch 173/500
# 7/7 [==============================] - 0s 9ms/step - loss: 1.8039e-04 - accuracy: 1.0000
# Epoch 174/500
# 7/7 [==============================] - 0s 8ms/step - loss: 1.7530e-04 - accuracy: 1.0000
# Epoch 175/500
# 7/7 [==============================] - 0s 9ms/step - loss: 1.7343e-04 - accuracy: 1.0000
# Epoch 176/500
# 7/7 [==============================] - 0s 9ms/step - loss: 1.7200e-04 - accuracy: 1.0000
# Epoch 177/500
# 7/7 [==============================] - 0s 9ms/step - loss: 1.6961e-04 - accuracy: 1.0000
# Epoch 178/500
# 7/7 [==============================] - 0s 9ms/step - loss: 1.7004e-04 - accuracy: 1.0000
# Epoch 179/500
# 7/7 [==============================] - 0s 8ms/step - loss: 1.6546e-04 - accuracy: 1.0000
# Epoch 180/500
# 7/7 [==============================] - 0s 10ms/step - loss: 1.6391e-04 - accuracy: 1.0000
# Epoch 181/500
# 7/7 [==============================] - 0s 8ms/step - loss: 1.6248e-04 - accuracy: 1.0000
# Epoch 182/500
# 7/7 [==============================] - 0s 8ms/step - loss: 1.6046e-04 - accuracy: 1.0000
# Epoch 183/500
# 7/7 [==============================] - 0s 12ms/step - loss: 1.5929e-04 - accuracy: 1.0000
# Epoch 184/500
# 7/7 [==============================] - 0s 9ms/step - loss: 1.5779e-04 - accuracy: 1.0000
# Epoch 185/500
# 7/7 [==============================] - 0s 10ms/step - loss: 1.5495e-04 - accuracy: 1.0000
# Epoch 186/500
# 7/7 [==============================] - 0s 8ms/step - loss: 1.5431e-04 - accuracy: 1.0000
# Epoch 187/500
# 7/7 [==============================] - 0s 9ms/step - loss: 1.5137e-04 - accuracy: 1.0000
# Epoch 188/500
# 7/7 [==============================] - 0s 9ms/step - loss: 1.5089e-04 - accuracy: 1.0000
# Epoch 189/500
# 7/7 [==============================] - 0s 10ms/step - loss: 1.5191e-04 - accuracy: 1.0000
# Epoch 190/500
# 7/7 [==============================] - 0s 9ms/step - loss: 1.4897e-04 - accuracy: 1.0000
# Epoch 191/500
# 7/7 [==============================] - 0s 10ms/step - loss: 1.4632e-04 - accuracy: 1.0000
# Epoch 192/500
# 7/7 [==============================] - 0s 10ms/step - loss: 1.4562e-04 - accuracy: 1.0000
# Epoch 193/500
# 7/7 [==============================] - 0s 9ms/step - loss: 1.4389e-04 - accuracy: 1.0000
# Epoch 194/500
# 7/7 [==============================] - 0s 8ms/step - loss: 1.4162e-04 - accuracy: 1.0000
# Epoch 195/500
# 7/7 [==============================] - 0s 10ms/step - loss: 1.3972e-04 - accuracy: 1.0000
# Epoch 196/500
# 7/7 [==============================] - 0s 8ms/step - loss: 1.3826e-04 - accuracy: 1.0000
# Epoch 197/500
# 7/7 [==============================] - 0s 10ms/step - loss: 1.3821e-04 - accuracy: 1.0000
# Epoch 198/500
# 7/7 [==============================] - 0s 9ms/step - loss: 1.3653e-04 - accuracy: 1.0000
# Epoch 199/500
# 7/7 [==============================] - 0s 9ms/step - loss: 1.3514e-04 - accuracy: 1.0000
# Epoch 200/500
# 7/7 [==============================] - 0s 10ms/step - loss: 1.3322e-04 - accuracy: 1.0000
# Epoch 201/500
# 7/7 [==============================] - 0s 8ms/step - loss: 1.3082e-04 - accuracy: 1.0000
# Epoch 202/500
# 7/7 [==============================] - 0s 8ms/step - loss: 1.2959e-04 - accuracy: 1.0000
# Epoch 203/500
# 7/7 [==============================] - 0s 8ms/step - loss: 1.2898e-04 - accuracy: 1.0000
# Epoch 204/500
# 7/7 [==============================] - 0s 8ms/step - loss: 1.2755e-04 - accuracy: 1.0000
# Epoch 205/500
# 7/7 [==============================] - 0s 10ms/step - loss: 1.2679e-04 - accuracy: 1.0000
# Epoch 206/500
# 7/7 [==============================] - 0s 8ms/step - loss: 1.2561e-04 - accuracy: 1.0000
# Epoch 207/500
# 7/7 [==============================] - 0s 8ms/step - loss: 1.2503e-04 - accuracy: 1.0000
# Epoch 208/500
# 7/7 [==============================] - 0s 9ms/step - loss: 1.2262e-04 - accuracy: 1.0000
# Epoch 209/500
# 7/7 [==============================] - 0s 8ms/step - loss: 1.2174e-04 - accuracy: 1.0000
# Epoch 210/500
# 7/7 [==============================] - 0s 10ms/step - loss: 1.2050e-04 - accuracy: 1.0000
# Epoch 211/500
# 7/7 [==============================] - 0s 10ms/step - loss: 1.1940e-04 - accuracy: 1.0000
# Epoch 212/500
# 7/7 [==============================] - 0s 11ms/step - loss: 1.1864e-04 - accuracy: 1.0000
# Epoch 213/500
# 7/7 [==============================] - 0s 8ms/step - loss: 1.1727e-04 - accuracy: 1.0000
# Epoch 214/500
# 7/7 [==============================] - 0s 8ms/step - loss: 1.1599e-04 - accuracy: 1.0000
# Epoch 215/500
# 7/7 [==============================] - 0s 8ms/step - loss: 1.1564e-04 - accuracy: 1.0000
# Epoch 216/500
# 7/7 [==============================] - 0s 8ms/step - loss: 1.1405e-04 - accuracy: 1.0000
# Epoch 217/500
# 7/7 [==============================] - 0s 10ms/step - loss: 1.1258e-04 - accuracy: 1.0000
# Epoch 218/500
# 7/7 [==============================] - 0s 8ms/step - loss: 1.1278e-04 - accuracy: 1.0000
# Epoch 219/500
# 7/7 [==============================] - 0s 8ms/step - loss: 1.1046e-04 - accuracy: 1.0000
# Epoch 220/500
# 7/7 [==============================] - 0s 8ms/step - loss: 1.0944e-04 - accuracy: 1.0000
# Epoch 221/500
# 7/7 [==============================] - 0s 8ms/step - loss: 1.0849e-04 - accuracy: 1.0000
# Epoch 222/500
# 7/7 [==============================] - 0s 10ms/step - loss: 1.0767e-04 - accuracy: 1.0000
# Epoch 223/500
# 7/7 [==============================] - 0s 8ms/step - loss: 1.0634e-04 - accuracy: 1.0000
# Epoch 224/500
# 7/7 [==============================] - 0s 11ms/step - loss: 1.0532e-04 - accuracy: 1.0000
# Epoch 225/500
# 7/7 [==============================] - 0s 8ms/step - loss: 1.0557e-04 - accuracy: 1.0000
# Epoch 226/500
# 7/7 [==============================] - 0s 12ms/step - loss: 1.0332e-04 - accuracy: 1.0000
# Epoch 227/500
# 7/7 [==============================] - 0s 8ms/step - loss: 1.0422e-04 - accuracy: 1.0000
# Epoch 228/500
# 7/7 [==============================] - 0s 9ms/step - loss: 1.0189e-04 - accuracy: 1.0000
# Epoch 229/500
# 7/7 [==============================] - 0s 9ms/step - loss: 1.0310e-04 - accuracy: 1.0000
# Epoch 230/500
# 7/7 [==============================] - 0s 8ms/step - loss: 1.0116e-04 - accuracy: 1.0000
# Epoch 231/500
# 7/7 [==============================] - 0s 8ms/step - loss: 1.0118e-04 - accuracy: 1.0000
# Epoch 232/500
# 7/7 [==============================] - 0s 8ms/step - loss: 9.8431e-05 - accuracy: 1.0000
# Epoch 233/500
# 7/7 [==============================] - 0s 11ms/step - loss: 9.7986e-05 - accuracy: 1.0000
# Epoch 234/500
# 7/7 [==============================] - 0s 8ms/step - loss: 9.7459e-05 - accuracy: 1.0000
# Epoch 235/500
# 7/7 [==============================] - 0s 9ms/step - loss: 9.6029e-05 - accuracy: 1.0000
# Epoch 236/500
# 7/7 [==============================] - 0s 8ms/step - loss: 9.5295e-05 - accuracy: 1.0000
# Epoch 237/500
# 7/7 [==============================] - 0s 9ms/step - loss: 9.4348e-05 - accuracy: 1.0000
# Epoch 238/500
# 7/7 [==============================] - 0s 8ms/step - loss: 9.3127e-05 - accuracy: 1.0000
# Epoch 239/500
# 7/7 [==============================] - 0s 8ms/step - loss: 9.3126e-05 - accuracy: 1.0000
# Epoch 240/500
# 7/7 [==============================] - 0s 11ms/step - loss: 9.2039e-05 - accuracy: 1.0000
# Epoch 241/500
# 7/7 [==============================] - 0s 9ms/step - loss: 9.1804e-05 - accuracy: 1.0000
# Epoch 242/500
# 7/7 [==============================] - 0s 8ms/step - loss: 9.0846e-05 - accuracy: 1.0000
# Epoch 243/500
# 7/7 [==============================] - 0s 10ms/step - loss: 9.0675e-05 - accuracy: 1.0000
# Epoch 244/500
# 7/7 [==============================] - 0s 12ms/step - loss: 9.0130e-05 - accuracy: 1.0000
# Epoch 245/500
# 7/7 [==============================] - 0s 9ms/step - loss: 8.8346e-05 - accuracy: 1.0000
# Epoch 246/500
# 7/7 [==============================] - 0s 10ms/step - loss: 8.7525e-05 - accuracy: 1.0000
# Epoch 247/500
# 7/7 [==============================] - 0s 8ms/step - loss: 8.6889e-05 - accuracy: 1.0000
# Epoch 248/500
# 7/7 [==============================] - 0s 11ms/step - loss: 8.6521e-05 - accuracy: 1.0000
# Epoch 249/500
# 7/7 [==============================] - 0s 11ms/step - loss: 8.6433e-05 - accuracy: 1.0000
# Epoch 250/500
# 7/7 [==============================] - 0s 10ms/step - loss: 8.5925e-05 - accuracy: 1.0000
# Epoch 251/500
# 7/7 [==============================] - 0s 11ms/step - loss: 8.5090e-05 - accuracy: 1.0000
# Epoch 252/500
# 7/7 [==============================] - 0s 9ms/step - loss: 8.4122e-05 - accuracy: 1.0000
# Epoch 253/500
# 7/7 [==============================] - 0s 12ms/step - loss: 8.3025e-05 - accuracy: 1.0000
# Epoch 254/500
# 7/7 [==============================] - 0s 11ms/step - loss: 8.2482e-05 - accuracy: 1.0000
# Epoch 255/500
# 7/7 [==============================] - 0s 10ms/step - loss: 8.2369e-05 - accuracy: 1.0000
# Epoch 256/500
# 7/7 [==============================] - 0s 10ms/step - loss: 8.1313e-05 - accuracy: 1.0000
# Epoch 257/500
# 7/7 [==============================] - 0s 11ms/step - loss: 8.1305e-05 - accuracy: 1.0000
# Epoch 258/500
# 7/7 [==============================] - 0s 13ms/step - loss: 7.9832e-05 - accuracy: 1.0000
# Epoch 259/500
# 7/7 [==============================] - 0s 9ms/step - loss: 7.9365e-05 - accuracy: 1.0000
# Epoch 260/500
# 7/7 [==============================] - 0s 8ms/step - loss: 7.8341e-05 - accuracy: 1.0000
# Epoch 261/500
# 7/7 [==============================] - 0s 10ms/step - loss: 7.7919e-05 - accuracy: 1.0000
# Epoch 262/500
# 7/7 [==============================] - 0s 10ms/step - loss: 7.7516e-05 - accuracy: 1.0000
# Epoch 263/500
# 7/7 [==============================] - 0s 10ms/step - loss: 7.7854e-05 - accuracy: 1.0000
# Epoch 264/500
# 7/7 [==============================] - 0s 8ms/step - loss: 7.7007e-05 - accuracy: 1.0000
# Epoch 265/500
# 7/7 [==============================] - 0s 10ms/step - loss: 7.5725e-05 - accuracy: 1.0000
# Epoch 266/500
# 7/7 [==============================] - 0s 8ms/step - loss: 7.5295e-05 - accuracy: 1.0000
# Epoch 267/500
# 7/7 [==============================] - 0s 9ms/step - loss: 7.4601e-05 - accuracy: 1.0000
# Epoch 268/500
# 7/7 [==============================] - 0s 10ms/step - loss: 7.4337e-05 - accuracy: 1.0000
# Epoch 269/500
# 7/7 [==============================] - 0s 10ms/step - loss: 7.3514e-05 - accuracy: 1.0000
# Epoch 270/500
# 7/7 [==============================] - 0s 8ms/step - loss: 7.4038e-05 - accuracy: 1.0000
# Epoch 271/500
# 7/7 [==============================] - 0s 10ms/step - loss: 7.2267e-05 - accuracy: 1.0000
# Epoch 272/500
# 7/7 [==============================] - 0s 10ms/step - loss: 7.1770e-05 - accuracy: 1.0000
# Epoch 273/500
# 7/7 [==============================] - 0s 9ms/step - loss: 7.2057e-05 - accuracy: 1.0000
# Epoch 274/500
# 7/7 [==============================] - 0s 9ms/step - loss: 7.2086e-05 - accuracy: 1.0000
# Epoch 275/500
# 7/7 [==============================] - 0s 9ms/step - loss: 7.0154e-05 - accuracy: 1.0000
# Epoch 276/500
# 7/7 [==============================] - 0s 10ms/step - loss: 6.9645e-05 - accuracy: 1.0000
# Epoch 277/500
# 7/7 [==============================] - 0s 8ms/step - loss: 6.9501e-05 - accuracy: 1.0000
# Epoch 278/500
# 7/7 [==============================] - 0s 9ms/step - loss: 6.8777e-05 - accuracy: 1.0000
# Epoch 279/500
# 7/7 [==============================] - 0s 8ms/step - loss: 6.8539e-05 - accuracy: 1.0000
# Epoch 280/500
# 7/7 [==============================] - 0s 8ms/step - loss: 6.8780e-05 - accuracy: 1.0000
# Epoch 281/500
# 7/7 [==============================] - 0s 8ms/step - loss: 6.7396e-05 - accuracy: 1.0000
# Epoch 282/500
# 7/7 [==============================] - 0s 11ms/step - loss: 6.7320e-05 - accuracy: 1.0000
# Epoch 283/500
# 7/7 [==============================] - 0s 10ms/step - loss: 6.6498e-05 - accuracy: 1.0000
# Epoch 284/500
# 7/7 [==============================] - 0s 9ms/step - loss: 6.5746e-05 - accuracy: 1.0000
# Epoch 285/500
# 7/7 [==============================] - 0s 10ms/step - loss: 6.5418e-05 - accuracy: 1.0000
# Epoch 286/500
# 7/7 [==============================] - 0s 8ms/step - loss: 6.4703e-05 - accuracy: 1.0000
# Epoch 287/500
# 7/7 [==============================] - 0s 9ms/step - loss: 6.4382e-05 - accuracy: 1.0000
# Epoch 288/500
# 7/7 [==============================] - 0s 9ms/step - loss: 6.4108e-05 - accuracy: 1.0000
# Epoch 289/500
# 7/7 [==============================] - 0s 9ms/step - loss: 6.3449e-05 - accuracy: 1.0000
# Epoch 290/500
# 7/7 [==============================] - 0s 8ms/step - loss: 6.3115e-05 - accuracy: 1.0000
# Epoch 291/500
# 7/7 [==============================] - 0s 8ms/step - loss: 6.2439e-05 - accuracy: 1.0000
# Epoch 292/500
# 7/7 [==============================] - 0s 8ms/step - loss: 6.2529e-05 - accuracy: 1.0000
# Epoch 293/500
# 7/7 [==============================] - 0s 9ms/step - loss: 6.2127e-05 - accuracy: 1.0000
# Epoch 294/500
# 7/7 [==============================] - 0s 11ms/step - loss: 6.1448e-05 - accuracy: 1.0000
# Epoch 295/500
# 7/7 [==============================] - 0s 12ms/step - loss: 6.0915e-05 - accuracy: 1.0000
# Epoch 296/500
# 7/7 [==============================] - 0s 10ms/step - loss: 6.0884e-05 - accuracy: 1.0000
# Epoch 297/500
# 7/7 [==============================] - 0s 9ms/step - loss: 6.0529e-05 - accuracy: 1.0000
# Epoch 298/500
# 7/7 [==============================] - 0s 8ms/step - loss: 5.9691e-05 - accuracy: 1.0000
# Epoch 299/500
# 7/7 [==============================] - 0s 11ms/step - loss: 5.9067e-05 - accuracy: 1.0000
# Epoch 300/500
# 7/7 [==============================] - 0s 10ms/step - loss: 5.9200e-05 - accuracy: 1.0000
# Epoch 301/500
# 7/7 [==============================] - 0s 10ms/step - loss: 5.8578e-05 - accuracy: 1.0000
# Epoch 302/500
# 7/7 [==============================] - 0s 9ms/step - loss: 5.8089e-05 - accuracy: 1.0000
# Epoch 303/500
# 7/7 [==============================] - 0s 13ms/step - loss: 5.8412e-05 - accuracy: 1.0000
# Epoch 304/500
# 7/7 [==============================] - 0s 9ms/step - loss: 5.8122e-05 - accuracy: 1.0000
# Epoch 305/500
# 7/7 [==============================] - 0s 10ms/step - loss: 5.7238e-05 - accuracy: 1.0000
# Epoch 306/500
# 7/7 [==============================] - 0s 9ms/step - loss: 5.6791e-05 - accuracy: 1.0000
# Epoch 307/500
# 7/7 [==============================] - 0s 11ms/step - loss: 5.6183e-05 - accuracy: 1.0000
# Epoch 308/500
# 7/7 [==============================] - 0s 9ms/step - loss: 5.6340e-05 - accuracy: 1.0000
# Epoch 309/500
# 7/7 [==============================] - 0s 11ms/step - loss: 5.5590e-05 - accuracy: 1.0000
# Epoch 310/500
# 7/7 [==============================] - 0s 9ms/step - loss: 5.5143e-05 - accuracy: 1.0000
# Epoch 311/500
# 7/7 [==============================] - 0s 12ms/step - loss: 5.4630e-05 - accuracy: 1.0000
# Epoch 312/500
# 7/7 [==============================] - 0s 9ms/step - loss: 5.4394e-05 - accuracy: 1.0000
# Epoch 313/500
# 7/7 [==============================] - 0s 10ms/step - loss: 5.4080e-05 - accuracy: 1.0000
# Epoch 314/500
# 7/7 [==============================] - 0s 10ms/step - loss: 5.3609e-05 - accuracy: 1.0000
# Epoch 315/500
# 7/7 [==============================] - 0s 9ms/step - loss: 5.3516e-05 - accuracy: 1.0000
# Epoch 316/500
# 7/7 [==============================] - 0s 9ms/step - loss: 5.3589e-05 - accuracy: 1.0000
# Epoch 317/500
# 7/7 [==============================] - 0s 11ms/step - loss: 5.2426e-05 - accuracy: 1.0000
# Epoch 318/500
# 7/7 [==============================] - 0s 9ms/step - loss: 5.2505e-05 - accuracy: 1.0000
# Epoch 319/500
# 7/7 [==============================] - 0s 10ms/step - loss: 5.1747e-05 - accuracy: 1.0000
# Epoch 320/500
# 7/7 [==============================] - 0s 9ms/step - loss: 5.2059e-05 - accuracy: 1.0000
# Epoch 321/500
# 7/7 [==============================] - 0s 11ms/step - loss: 5.1362e-05 - accuracy: 1.0000
# Epoch 322/500
# 7/7 [==============================] - 0s 12ms/step - loss: 5.0915e-05 - accuracy: 1.0000
# Epoch 323/500
# 7/7 [==============================] - 0s 10ms/step - loss: 5.0467e-05 - accuracy: 1.0000
# Epoch 324/500
# 7/7 [==============================] - 0s 11ms/step - loss: 5.0188e-05 - accuracy: 1.0000
# Epoch 325/500
# 7/7 [==============================] - 0s 9ms/step - loss: 4.9899e-05 - accuracy: 1.0000
# Epoch 326/500
# 7/7 [==============================] - 0s 9ms/step - loss: 4.9503e-05 - accuracy: 1.0000
# Epoch 327/500
# 7/7 [==============================] - 0s 9ms/step - loss: 4.9345e-05 - accuracy: 1.0000
# Epoch 328/500
# 7/7 [==============================] - 0s 9ms/step - loss: 4.9050e-05 - accuracy: 1.0000
# Epoch 329/500
# 7/7 [==============================] - 0s 8ms/step - loss: 4.8738e-05 - accuracy: 1.0000
# Epoch 330/500
# 7/7 [==============================] - 0s 10ms/step - loss: 4.8344e-05 - accuracy: 1.0000
# Epoch 331/500
# 7/7 [==============================] - 0s 8ms/step - loss: 4.7801e-05 - accuracy: 1.0000
# Epoch 332/500
# 7/7 [==============================] - 0s 10ms/step - loss: 4.8059e-05 - accuracy: 1.0000
# Epoch 333/500
# 7/7 [==============================] - 0s 11ms/step - loss: 4.7636e-05 - accuracy: 1.0000
# Epoch 334/500
# 7/7 [==============================] - 0s 11ms/step - loss: 4.6966e-05 - accuracy: 1.0000
# Epoch 335/500
# 7/7 [==============================] - 0s 8ms/step - loss: 4.6742e-05 - accuracy: 1.0000
# Epoch 336/500
# 7/7 [==============================] - 0s 11ms/step - loss: 4.6595e-05 - accuracy: 1.0000
# Epoch 337/500
# 7/7 [==============================] - 0s 10ms/step - loss: 4.6204e-05 - accuracy: 1.0000
# Epoch 338/500
# 7/7 [==============================] - 0s 9ms/step - loss: 4.6269e-05 - accuracy: 1.0000
# Epoch 339/500
# 7/7 [==============================] - 0s 10ms/step - loss: 4.5722e-05 - accuracy: 1.0000
# Epoch 340/500
# 7/7 [==============================] - 0s 8ms/step - loss: 4.5443e-05 - accuracy: 1.0000
# Epoch 341/500
# 7/7 [==============================] - 0s 10ms/step - loss: 4.5288e-05 - accuracy: 1.0000
# Epoch 342/500
# 7/7 [==============================] - 0s 9ms/step - loss: 4.5648e-05 - accuracy: 1.0000
# Epoch 343/500
# 7/7 [==============================] - 0s 11ms/step - loss: 4.4616e-05 - accuracy: 1.0000
# Epoch 344/500
# 7/7 [==============================] - 0s 9ms/step - loss: 4.4333e-05 - accuracy: 1.0000
# Epoch 345/500
# 7/7 [==============================] - 0s 11ms/step - loss: 4.3801e-05 - accuracy: 1.0000
# Epoch 346/500
# 7/7 [==============================] - 0s 8ms/step - loss: 4.3583e-05 - accuracy: 1.0000
# Epoch 347/500
# 7/7 [==============================] - 0s 9ms/step - loss: 4.3397e-05 - accuracy: 1.0000
# Epoch 348/500
# 7/7 [==============================] - 0s 9ms/step - loss: 4.3057e-05 - accuracy: 1.0000
# Epoch 349/500
# 7/7 [==============================] - 0s 12ms/step - loss: 4.2717e-05 - accuracy: 1.0000
# Epoch 350/500
# 7/7 [==============================] - 0s 9ms/step - loss: 4.2448e-05 - accuracy: 1.0000
# Epoch 351/500
# 7/7 [==============================] - 0s 8ms/step - loss: 4.2195e-05 - accuracy: 1.0000
# Epoch 352/500
# 7/7 [==============================] - 0s 11ms/step - loss: 4.1968e-05 - accuracy: 1.0000
# Epoch 353/500
# 7/7 [==============================] - 0s 8ms/step - loss: 4.1687e-05 - accuracy: 1.0000
# Epoch 354/500
# 7/7 [==============================] - 0s 9ms/step - loss: 4.1410e-05 - accuracy: 1.0000
# Epoch 355/500
# 7/7 [==============================] - 0s 9ms/step - loss: 4.1293e-05 - accuracy: 1.0000
# Epoch 356/500
# 7/7 [==============================] - 0s 9ms/step - loss: 4.0950e-05 - accuracy: 1.0000
# Epoch 357/500
# 7/7 [==============================] - 0s 10ms/step - loss: 4.0640e-05 - accuracy: 1.0000
# Epoch 358/500
# 7/7 [==============================] - 0s 8ms/step - loss: 4.0493e-05 - accuracy: 1.0000
# Epoch 359/500
# 7/7 [==============================] - 0s 10ms/step - loss: 4.0370e-05 - accuracy: 1.0000
# Epoch 360/500
# 7/7 [==============================] - 0s 9ms/step - loss: 4.0219e-05 - accuracy: 1.0000
# Epoch 361/500
# 7/7 [==============================] - 0s 11ms/step - loss: 3.9991e-05 - accuracy: 1.0000
# Epoch 362/500
# 7/7 [==============================] - 0s 9ms/step - loss: 3.9418e-05 - accuracy: 1.0000
# Epoch 363/500
# 7/7 [==============================] - 0s 13ms/step - loss: 3.9189e-05 - accuracy: 1.0000
# Epoch 364/500
# 7/7 [==============================] - 0s 8ms/step - loss: 3.9264e-05 - accuracy: 1.0000
# Epoch 365/500
# 7/7 [==============================] - 0s 10ms/step - loss: 3.9074e-05 - accuracy: 1.0000
# Epoch 366/500
# 7/7 [==============================] - 0s 8ms/step - loss: 3.8785e-05 - accuracy: 1.0000
# Epoch 367/500
# 7/7 [==============================] - 0s 9ms/step - loss: 3.8285e-05 - accuracy: 1.0000
# Epoch 368/500
# 7/7 [==============================] - 0s 9ms/step - loss: 3.8305e-05 - accuracy: 1.0000
# Epoch 369/500
# 7/7 [==============================] - 0s 10ms/step - loss: 3.8135e-05 - accuracy: 1.0000
# Epoch 370/500
# 7/7 [==============================] - 0s 8ms/step - loss: 3.7594e-05 - accuracy: 1.0000
# Epoch 371/500
# 7/7 [==============================] - 0s 8ms/step - loss: 3.7373e-05 - accuracy: 1.0000
# Epoch 372/500
# 7/7 [==============================] - 0s 9ms/step - loss: 3.7532e-05 - accuracy: 1.0000
# Epoch 373/500
# 7/7 [==============================] - 0s 10ms/step - loss: 3.6718e-05 - accuracy: 1.0000
# Epoch 374/500
# 7/7 [==============================] - 0s 10ms/step - loss: 3.6464e-05 - accuracy: 1.0000
# Epoch 375/500
# 7/7 [==============================] - 0s 11ms/step - loss: 3.7100e-05 - accuracy: 1.0000
# Epoch 376/500
# 7/7 [==============================] - 0s 10ms/step - loss: 3.6546e-05 - accuracy: 1.0000
# Epoch 377/500
# 7/7 [==============================] - 0s 10ms/step - loss: 3.6557e-05 - accuracy: 1.0000
# Epoch 378/500
# 7/7 [==============================] - 0s 9ms/step - loss: 3.5969e-05 - accuracy: 1.0000
# Epoch 379/500
# 7/7 [==============================] - 0s 9ms/step - loss: 3.5860e-05 - accuracy: 1.0000
# Epoch 380/500
# 7/7 [==============================] - 0s 10ms/step - loss: 3.5774e-05 - accuracy: 1.0000
# Epoch 381/500
# 7/7 [==============================] - 0s 9ms/step - loss: 3.5584e-05 - accuracy: 1.0000
# Epoch 382/500
# 7/7 [==============================] - 0s 9ms/step - loss: 3.5283e-05 - accuracy: 1.0000
# Epoch 383/500
# 7/7 [==============================] - 0s 8ms/step - loss: 3.4990e-05 - accuracy: 1.0000
# Epoch 384/500
# 7/7 [==============================] - 0s 11ms/step - loss: 3.5080e-05 - accuracy: 1.0000
# Epoch 385/500
# 7/7 [==============================] - 0s 9ms/step - loss: 3.4520e-05 - accuracy: 1.0000
# Epoch 386/500
# 7/7 [==============================] - 0s 8ms/step - loss: 3.4125e-05 - accuracy: 1.0000
# Epoch 387/500
# 7/7 [==============================] - 0s 12ms/step - loss: 3.4090e-05 - accuracy: 1.0000
# Epoch 388/500
# 7/7 [==============================] - 0s 8ms/step - loss: 3.3847e-05 - accuracy: 1.0000
# Epoch 389/500
# 7/7 [==============================] - 0s 10ms/step - loss: 3.3400e-05 - accuracy: 1.0000
# Epoch 390/500
# 7/7 [==============================] - 0s 12ms/step - loss: 3.3429e-05 - accuracy: 1.0000
# Epoch 391/500
# 7/7 [==============================] - 0s 10ms/step - loss: 3.3135e-05 - accuracy: 1.0000
# Epoch 392/500
# 7/7 [==============================] - 0s 12ms/step - loss: 3.2667e-05 - accuracy: 1.0000
# Epoch 393/500
# 7/7 [==============================] - 0s 10ms/step - loss: 3.2659e-05 - accuracy: 1.0000
# Epoch 394/500
# 7/7 [==============================] - 0s 10ms/step - loss: 3.2491e-05 - accuracy: 1.0000
# Epoch 395/500
# 7/7 [==============================] - 0s 9ms/step - loss: 3.2342e-05 - accuracy: 1.0000
# Epoch 396/500
# 7/7 [==============================] - 0s 11ms/step - loss: 3.2145e-05 - accuracy: 1.0000
# Epoch 397/500
# 7/7 [==============================] - 0s 9ms/step - loss: 3.2089e-05 - accuracy: 1.0000
# Epoch 398/500
# 7/7 [==============================] - 0s 9ms/step - loss: 3.1738e-05 - accuracy: 1.0000
# Epoch 399/500
# 7/7 [==============================] - 0s 9ms/step - loss: 3.1695e-05 - accuracy: 1.0000
# Epoch 400/500
# 7/7 [==============================] - 0s 10ms/step - loss: 3.1332e-05 - accuracy: 1.0000
# Epoch 401/500
# 7/7 [==============================] - 0s 11ms/step - loss: 3.1243e-05 - accuracy: 1.0000
# Epoch 402/500
# 7/7 [==============================] - 0s 10ms/step - loss: 3.1407e-05 - accuracy: 1.0000
# Epoch 403/500
# 7/7 [==============================] - 0s 12ms/step - loss: 3.1075e-05 - accuracy: 1.0000
# Epoch 404/500
# 7/7 [==============================] - 0s 9ms/step - loss: 3.0857e-05 - accuracy: 1.0000
# Epoch 405/500
# 7/7 [==============================] - 0s 12ms/step - loss: 3.0386e-05 - accuracy: 1.0000
# Epoch 406/500
# 7/7 [==============================] - 0s 10ms/step - loss: 3.0319e-05 - accuracy: 1.0000
# Epoch 407/500
# 7/7 [==============================] - 0s 11ms/step - loss: 3.0244e-05 - accuracy: 1.0000
# Epoch 408/500
# 7/7 [==============================] - 0s 9ms/step - loss: 3.0264e-05 - accuracy: 1.0000
# Epoch 409/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.9827e-05 - accuracy: 1.0000
# Epoch 410/500
# 7/7 [==============================] - 0s 10ms/step - loss: 2.9684e-05 - accuracy: 1.0000
# Epoch 411/500
# 7/7 [==============================] - 0s 10ms/step - loss: 2.9538e-05 - accuracy: 1.0000
# Epoch 412/500
# 7/7 [==============================] - 0s 11ms/step - loss: 2.9410e-05 - accuracy: 1.0000
# Epoch 413/500
# 7/7 [==============================] - 0s 8ms/step - loss: 2.9345e-05 - accuracy: 1.0000
# Epoch 414/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.9064e-05 - accuracy: 1.0000
# Epoch 415/500
# 7/7 [==============================] - 0s 11ms/step - loss: 2.9519e-05 - accuracy: 1.0000
# Epoch 416/500
# 7/7 [==============================] - 0s 11ms/step - loss: 2.8440e-05 - accuracy: 1.0000
# Epoch 417/500
# 7/7 [==============================] - 0s 10ms/step - loss: 2.8480e-05 - accuracy: 1.0000
# Epoch 418/500
# 7/7 [==============================] - 0s 8ms/step - loss: 2.8279e-05 - accuracy: 1.0000
# Epoch 419/500
# 7/7 [==============================] - 0s 11ms/step - loss: 2.8116e-05 - accuracy: 1.0000
# Epoch 420/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.7892e-05 - accuracy: 1.0000
# Epoch 421/500
# 7/7 [==============================] - 0s 10ms/step - loss: 2.7891e-05 - accuracy: 1.0000
# Epoch 422/500
# 7/7 [==============================] - 0s 8ms/step - loss: 2.7730e-05 - accuracy: 1.0000
# Epoch 423/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.7551e-05 - accuracy: 1.0000
# Epoch 424/500
# 7/7 [==============================] - 0s 8ms/step - loss: 2.7242e-05 - accuracy: 1.0000
# Epoch 425/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.7268e-05 - accuracy: 1.0000
# Epoch 426/500
# 7/7 [==============================] - 0s 8ms/step - loss: 2.7117e-05 - accuracy: 1.0000
# Epoch 427/500
# 7/7 [==============================] - 0s 10ms/step - loss: 2.7253e-05 - accuracy: 1.0000
# Epoch 428/500
# 7/7 [==============================] - 0s 12ms/step - loss: 2.6796e-05 - accuracy: 1.0000
# Epoch 429/500
# 7/7 [==============================] - 0s 11ms/step - loss: 2.6622e-05 - accuracy: 1.0000
# Epoch 430/500
# 7/7 [==============================] - 0s 10ms/step - loss: 2.6468e-05 - accuracy: 1.0000
# Epoch 431/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.6217e-05 - accuracy: 1.0000
# Epoch 432/500
# 7/7 [==============================] - 0s 10ms/step - loss: 2.6232e-05 - accuracy: 1.0000
# Epoch 433/500
# 7/7 [==============================] - 0s 10ms/step - loss: 2.5899e-05 - accuracy: 1.0000
# Epoch 434/500
# 7/7 [==============================] - 0s 11ms/step - loss: 2.5892e-05 - accuracy: 1.0000
# Epoch 435/500
# 7/7 [==============================] - 0s 13ms/step - loss: 2.5686e-05 - accuracy: 1.0000
# Epoch 436/500
# 7/7 [==============================] - 0s 10ms/step - loss: 2.5528e-05 - accuracy: 1.0000
# Epoch 437/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.5490e-05 - accuracy: 1.0000
# Epoch 438/500
# 7/7 [==============================] - 0s 10ms/step - loss: 2.5272e-05 - accuracy: 1.0000
# Epoch 439/500
# 7/7 [==============================] - 0s 11ms/step - loss: 2.5365e-05 - accuracy: 1.0000
# Epoch 440/500
# 7/7 [==============================] - 0s 10ms/step - loss: 2.5192e-05 - accuracy: 1.0000
# Epoch 441/500
# 7/7 [==============================] - 0s 11ms/step - loss: 2.4849e-05 - accuracy: 1.0000
# Epoch 442/500
# 7/7 [==============================] - 0s 11ms/step - loss: 2.4817e-05 - accuracy: 1.0000
# Epoch 443/500
# 7/7 [==============================] - 0s 11ms/step - loss: 2.4570e-05 - accuracy: 1.0000
# Epoch 444/500
# 7/7 [==============================] - 0s 11ms/step - loss: 2.4464e-05 - accuracy: 1.0000
# Epoch 445/500
# 7/7 [==============================] - 0s 10ms/step - loss: 2.4371e-05 - accuracy: 1.0000
# Epoch 446/500
# 7/7 [==============================] - 0s 10ms/step - loss: 2.4317e-05 - accuracy: 1.0000
# Epoch 447/500
# 7/7 [==============================] - 0s 10ms/step - loss: 2.4210e-05 - accuracy: 1.0000
# Epoch 448/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.3941e-05 - accuracy: 1.0000
# Epoch 449/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.3888e-05 - accuracy: 1.0000
# Epoch 450/500
# 7/7 [==============================] - 0s 12ms/step - loss: 2.3828e-05 - accuracy: 1.0000
# Epoch 451/500
# 7/7 [==============================] - 0s 8ms/step - loss: 2.3678e-05 - accuracy: 1.0000
# Epoch 452/500
# 7/7 [==============================] - 0s 8ms/step - loss: 2.3499e-05 - accuracy: 1.0000
# Epoch 453/500
# 7/7 [==============================] - 0s 12ms/step - loss: 2.3482e-05 - accuracy: 1.0000
# Epoch 454/500
# 7/7 [==============================] - 0s 8ms/step - loss: 2.3190e-05 - accuracy: 1.0000
# Epoch 455/500
# 7/7 [==============================] - 0s 13ms/step - loss: 2.3106e-05 - accuracy: 1.0000
# Epoch 456/500
# 7/7 [==============================] - 0s 8ms/step - loss: 2.2912e-05 - accuracy: 1.0000
# Epoch 457/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.2849e-05 - accuracy: 1.0000
# Epoch 458/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.2727e-05 - accuracy: 1.0000
# Epoch 459/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.2542e-05 - accuracy: 1.0000
# Epoch 460/500
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2380e-05 - accuracy: 1.0000
# Epoch 461/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.2332e-05 - accuracy: 1.0000
# Epoch 462/500
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2229e-05 - accuracy: 1.0000
# Epoch 463/500
# 7/7 [==============================] - 0s 8ms/step - loss: 2.2070e-05 - accuracy: 1.0000
# Epoch 464/500
# 7/7 [==============================] - 0s 10ms/step - loss: 2.1865e-05 - accuracy: 1.0000
# Epoch 465/500
# 7/7 [==============================] - 0s 10ms/step - loss: 2.1814e-05 - accuracy: 1.0000
# Epoch 466/500
# 7/7 [==============================] - 0s 12ms/step - loss: 2.1760e-05 - accuracy: 1.0000
# Epoch 467/500
# 7/7 [==============================] - 0s 10ms/step - loss: 2.1730e-05 - accuracy: 1.0000
# Epoch 468/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.1545e-05 - accuracy: 1.0000
# Epoch 469/500
# 7/7 [==============================] - 0s 11ms/step - loss: 2.1470e-05 - accuracy: 1.0000
# Epoch 470/500
# 7/7 [==============================] - 0s 10ms/step - loss: 2.1141e-05 - accuracy: 1.0000
# Epoch 471/500
# 7/7 [==============================] - 0s 8ms/step - loss: 2.1622e-05 - accuracy: 1.0000
# Epoch 472/500
# 7/7 [==============================] - 0s 10ms/step - loss: 2.1695e-05 - accuracy: 1.0000
# Epoch 473/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.0938e-05 - accuracy: 1.0000
# Epoch 474/500
# 7/7 [==============================] - 0s 10ms/step - loss: 2.0868e-05 - accuracy: 1.0000
# Epoch 475/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.0720e-05 - accuracy: 1.0000
# Epoch 476/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.0505e-05 - accuracy: 1.0000
# Epoch 477/500
# 7/7 [==============================] - 0s 12ms/step - loss: 2.0486e-05 - accuracy: 1.0000
# Epoch 478/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.0588e-05 - accuracy: 1.0000
# Epoch 479/500
# 7/7 [==============================] - 0s 11ms/step - loss: 2.0188e-05 - accuracy: 1.0000
# Epoch 480/500
# 7/7 [==============================] - 0s 8ms/step - loss: 2.0362e-05 - accuracy: 1.0000
# Epoch 481/500
# 7/7 [==============================] - 0s 8ms/step - loss: 2.0104e-05 - accuracy: 1.0000
# Epoch 482/500
# 7/7 [==============================] - 0s 10ms/step - loss: 1.9853e-05 - accuracy: 1.0000
# Epoch 483/500
# 7/7 [==============================] - 0s 9ms/step - loss: 1.9793e-05 - accuracy: 1.0000
# Epoch 484/500
# 7/7 [==============================] - 0s 10ms/step - loss: 1.9824e-05 - accuracy: 1.0000
# Epoch 485/500
# 7/7 [==============================] - 0s 10ms/step - loss: 1.9708e-05 - accuracy: 1.0000
# Epoch 486/500
# 7/7 [==============================] - 0s 11ms/step - loss: 1.9646e-05 - accuracy: 1.0000
# Epoch 487/500
# 7/7 [==============================] - 0s 12ms/step - loss: 1.9585e-05 - accuracy: 1.0000
# Epoch 488/500
# 7/7 [==============================] - 0s 8ms/step - loss: 1.9478e-05 - accuracy: 1.0000
# Epoch 489/500
# 7/7 [==============================] - 0s 10ms/step - loss: 1.9330e-05 - accuracy: 1.0000
# Epoch 490/500
# 7/7 [==============================] - 0s 12ms/step - loss: 1.9187e-05 - accuracy: 1.0000
# Epoch 491/500
# 7/7 [==============================] - 0s 11ms/step - loss: 1.9065e-05 - accuracy: 1.0000
# Epoch 492/500
# 7/7 [==============================] - 0s 11ms/step - loss: 1.8969e-05 - accuracy: 1.0000
# Epoch 493/500
# 7/7 [==============================] - 0s 10ms/step - loss: 1.8796e-05 - accuracy: 1.0000
# Epoch 494/500
# 7/7 [==============================] - 0s 11ms/step - loss: 1.8676e-05 - accuracy: 1.0000
# Epoch 495/500
# 7/7 [==============================] - 0s 13ms/step - loss: 1.8661e-05 - accuracy: 1.0000
# Epoch 496/500
# 7/7 [==============================] - 0s 9ms/step - loss: 1.8766e-05 - accuracy: 1.0000
# Epoch 497/500
# 7/7 [==============================] - 0s 12ms/step - loss: 1.8410e-05 - accuracy: 1.0000
# Epoch 498/500
# 7/7 [==============================] - 0s 12ms/step - loss: 1.8352e-05 - accuracy: 1.0000
# Epoch 499/500
# 7/7 [==============================] - 0s 12ms/step - loss: 1.8297e-05 - accuracy: 1.0000
# Epoch 500/500
# 7/7 [==============================] - 0s 9ms/step - loss: 1.8151e-05 - accuracy: 1.0000
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-100-39b1781d2ec3> in <module>()
#       8 plt.figure()
#       9 plt.plot(history.history['loss'])
# ---> 10 plt.plot(history.history['val_loss'])
#      11 plt.legend(['loss','val_loss'])
#
# KeyError: 'val_loss'

# %% [markdown]
# ### 4. test ###
# Now that both models are trained, let us test their performance using our test dataset. The test dataset is never used to train the models, and reflects the acutual performance of the model when it is used in the general images.
#
# To evaluate the model , we can use
# `cat_model.evaluate(test_x,test_y)`.
#
# **Exercise**: Please evaluate the model with regularization.

# %%
cat_model.evaluate(test_x,test_y)
# Out:
# 2/2 [==============================] - 0s 6ms/step - loss: 3.2186 - accuracy: 0.7400
# [3.218640089035034, 0.7400000095367432]

# %% [markdown]
# The expected accuracy is higher than 0.7. If the accuracy is lower than 0.7, you may want to increase the epoch number, adjust the learning rate, and the regularizer weight, to achieve the goal.
#
# For your reference, I trained the model for 5 min to achieve that goal.
#
# If you have achieved the 0.7 goal, I would like to challenge you for the 0.8 accuracy for the test set.
